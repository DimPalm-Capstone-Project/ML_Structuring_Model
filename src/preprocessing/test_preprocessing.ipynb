# %%
from palm_processor import PalmPreprocessor

# Inisialisasi preprocessor
preprocessor = PalmPreprocessor(target_size=(128, 128))

# Test pada satu gambar
image_path = "../../data/raw/DATASET-009.JPG"

# 1. Preprocessing gambar
print("Processing image...")
processed_image = preprocessor.preprocess_image(image_path)

if processed_image is not None:
    # 2. Generate augmentasi
    print("\nGenerating augmentations...")
    augmented_images = preprocessor.generate_augmentations(processed_image)
    
    # 3. Simpan hasil
    print("\nSaving results...")
    person_id = preprocessor.save_augmented_images(augmented_images, base_dir='../../data')
    print(f"\nDone! Person ID: {person_id}")
else:
    print("Preprocessing failed!")
# Out:
# Processing image...
# Generating augmentations...
# INFO:palm_processor:Saved: data_035_1.jpg (original)
# INFO:palm_processor:Saved: data_035_2.jpg (rotate_-15°)
# INFO:palm_processor:Saved: data_035_3.jpg (rotate_-10°)
# INFO:palm_processor:Saved: data_035_4.jpg (rotate_-5°)
# INFO:palm_processor:Saved: data_035_5.jpg (rotate_5°)
# INFO:palm_processor:Saved: data_035_6.jpg (rotate_10°)
# INFO:palm_processor:Saved: data_035_7.jpg (rotate_15°)
# INFO:palm_processor:Saved: data_035_8.jpg (scale_0.95)
# INFO:palm_processor:Saved: data_035_9.jpg (scale_1.05)
# INFO:palm_processor:Saved: data_035_10.jpg (scale_1.1)
# INFO:palm_processor:Saved: data_035_11.jpg (darker_10%)
# INFO:palm_processor:Saved: data_035_12.jpg (darker_5%)
# INFO:palm_processor:Saved: data_035_13.jpg (brighter_5%)
# INFO:palm_processor:Saved: data_035_14.jpg (brighter_10%)
# INFO:palm_processor:Saved: data_035_15.jpg (contrast_higher_5%)
# INFO:palm_processor:Saved: data_035_16.jpg (contrast_higher_10%)
# INFO:palm_processor:Saved: data_035_17.jpg (rotate_-5°_darker_5%)
# INFO:palm_processor:Saved: data_035_18.jpg (rotate_-5°_brighter_5%)
# INFO:palm_processor:Saved: data_035_19.jpg (rotate_5°_darker_5%)
# INFO:palm_processor:Saved: data_035_20.jpg (rotate_5°_brighter_5%)
# INFO:palm_processor:
# Saved 20 images in: person_035
# Total augmented images generated: 20
# 1. original
# 2. rotate_-15°
# 3. rotate_-10°
# 4. rotate_-5°
# 5. rotate_5°
# 6. rotate_10°
# 7. rotate_15°
# 8. scale_0.95
# 9. scale_1.05
# 10. scale_1.1
# 11. darker_10%
# 12. darker_5%
# 13. brighter_5%
# 14. brighter_10%
# 15. contrast_higher_5%
# 16. contrast_higher_10%
# 17. rotate_-5°_darker_5%
# 18. rotate_-5°_brighter_5%
# 19. rotate_5°_darker_5%
# 20. rotate_5°_brighter_5%
#
# Saving results...
#
# Done! Person ID: 035
